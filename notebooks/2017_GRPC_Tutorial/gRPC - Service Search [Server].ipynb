# %%
import logging 
import sys

# Create logger
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

# Create STDERR handler
handler = logging.StreamHandler(sys.stderr)

# Create formatter and add it to the handler
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

# Set STDERR handler as the only handler 
logger.handlers = [handler]

# %%
! TUTORIAL_GRPC_PG_PORT=2345 pipenv run python /opt/notebooks/2017_GRPC_Tutorial/src/tutorial/grpc/geodatas/search_server.py
# Out:
# /root/.local/share/virtualenvs/2017_GRPC_Tutorial-oVeYm3ns/lib/python3.7/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# 2019-02-22 00:13:42,311 INFO sqlalchemy.engine.base.Engine select version()
# 2019-02-22 00:13:42,311 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:13:42,312 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2019-02-22 00:13:42,312 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:13:42,313 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2019-02-22 00:13:42,313 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:13:42,314 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2019-02-22 00:13:42,314 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:13:42,314 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2019-02-22 00:13:42,314 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:13:42,315 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2019-02-22 00:13:42,315 INFO sqlalchemy.engine.base.Engine {'name': 'thing'}
# 2019-02-22 00:13:42,370 - tutorial.grpc.geodatas.tools.service_discovery - INFO - register started
# 2019-02-22 00:13:42,370 - root - DEBUG - consul_host=127.0.0.1
# 2019-02-22 00:13:42,374 - urllib3.connectionpool - DEBUG - Starting new HTTP connection (1): 127.0.0.1:8500
# 2019-02-22 00:13:42,395 - urllib3.connectionpool - DEBUG - http://127.0.0.1:8500 "PUT /v1/agent/service/register HTTP/1.1" 200 0
# 2019-02-22 00:13:42,397 - urllib3.connectionpool - DEBUG - http://127.0.0.1:8500 "GET /v1/agent/services HTTP/1.1" 200 182
# 2019-02-22 00:13:42,398 - tutorial.grpc.geodatas.tools.service_discovery - INFO - services: {'search-service-52716': {'ID': 'search-service-52716', 'Service': 'search-service', 'Tags': [], 'Meta': {}, 'Port': 52716, 'Address': '127.0.0.1', 'Weights': {'Passing': 1, 'Warning': 1}, 'EnableTagOverride': False}, 'search-service-54808': {'ID': 'search-service-54808', 'Service': 'search-service', 'Tags': [], 'Meta': {}, 'Port': 54808, 'Address': '127.0.0.1', 'Weights': {'Passing': 1, 'Warning': 1}, 'EnableTagOverride': False}}
# 2019-02-22 00:13:42,400 - __main__ - INFO - Search service, version=0.1.0
# 2019-02-22 00:13:42,421 - __main__ - INFO - Starting server on port 54808...
# 2019-02-22 00:13:42,423 - __main__ - INFO - Ready and waiting for connections.
# 2019-02-22 00:14:23,024 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-02-22 00:14:23,024 - sqlalchemy.engine.base.Engine - INFO - BEGIN (implicit)
# 2019-02-22 00:14:23,026 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,026 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,026 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,026 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,034 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,036 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,036 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,036 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,036 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,048 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,063 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,063 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,063 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,063 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,069 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,071 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,071 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,071 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,071 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,073 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,089 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,089 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,090 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,090 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,095 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,096 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,096 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,097 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,097 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,098 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,111 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,111 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,111 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,111 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,116 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,118 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,118 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,118 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,118 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,120 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,143 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,143 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,143 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,143 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,149 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,151 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,151 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,151 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,151 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,153 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,165 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,165 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,165 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,165 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,170 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,175 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,175 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,176 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,176 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,177 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,191 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,191 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,191 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,191 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,201 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,203 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,203 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,203 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,203 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,204 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,215 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,215 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,215 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,215 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,219 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,227 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,227 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,227 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,227 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,229 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,249 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,249 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,249 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,249 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,258 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,259 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,259 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,259 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,259 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,261 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,274 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,274 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,274 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,274 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,280 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,281 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,281 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,282 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,282 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,284 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,299 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,299 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,299 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,299 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,303 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,305 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,305 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,306 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,306 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,308 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,328 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,328 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,328 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,328 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,332 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,334 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,334 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,334 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,334 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,336 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,355 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,355 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,356 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,356 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,362 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,363 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,363 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,364 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,364 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,366 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,382 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,382 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,382 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,382 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,387 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,389 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,389 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,389 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,389 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,391 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,411 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,411 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,411 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,411 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,420 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,420 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,420 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,421 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,421 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,426 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,436 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,436 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,436 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,436 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,446 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,448 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,448 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,448 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,448 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,450 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,472 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,472 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,472 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,472 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,482 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,483 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,483 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,484 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,484 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,485 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,499 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,499 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,499 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,499 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,510 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,511 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,511 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,511 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,511 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,513 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,532 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,532 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,533 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,533 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,542 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,544 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,544 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,544 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,544 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,547 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,571 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,571 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,575 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,575 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,582 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,583 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,583 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,584 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,584 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,586 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,605 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,605 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,608 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,608 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,617 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,619 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,619 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,619 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,619 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,624 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,638 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,638 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,639 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,639 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,644 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,646 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,646 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,646 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,646 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,649 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,662 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,662 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,662 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,662 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,668 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,670 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,670 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,670 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,670 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,672 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,688 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,688 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,688 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,688 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,693 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,695 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,695 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,695 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,695 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,697 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,710 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,710 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,711 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,711 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,716 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,718 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,718 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,718 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,718 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,721 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,749 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,749 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,749 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,749 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,759 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,760 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,760 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,761 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,761 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,763 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,779 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,779 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,779 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,779 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,790 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,792 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,792 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,792 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,792 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,794 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,811 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,811 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,811 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,811 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,817 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,819 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,819 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,819 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,819 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,822 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,836 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,836 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,837 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,837 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,843 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,844 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,844 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,845 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,845 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:23,847 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:23,868 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,868 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:23,868 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:23,868 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:23,878 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,879 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:23,879 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# ...
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:25,515 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:25,515 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:25,515 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:25,522 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,523 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:25,523 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:25,523 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:25,523 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:25,526 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:25,541 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:25,541 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:25,541 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:25,541 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:25,545 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,546 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:25,546 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:25,547 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:25,547 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:25,548 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:25,563 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:25,563 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:25,563 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:25,563 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:25,568 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,569 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:25,569 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:25,570 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:25,570 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:25,572 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:25,585 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:25,585 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:25,585 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:25,585 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:25,593 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,595 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:25,595 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:25,595 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:25,595 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:25,597 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:25,612 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:25,612 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:25,612 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:25,612 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:25,618 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,619 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:25,619 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:25,619 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:25,619 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:25,622 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:25,635 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:25,635 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:25,636 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:25,636 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:25,642 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,643 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:25,643 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:25,643 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:25,643 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:25,645 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:25,656 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:25,656 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:25,656 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:25,656 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:25,660 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,662 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:25,662 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:25,662 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:25,662 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:25,664 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:25,678 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:25,678 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:25,678 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:25,678 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:25,684 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,685 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:25,685 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:25,686 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:25,686 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:25,688 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:25,701 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:25,701 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:25,702 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:25,702 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:25,715 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
# 2019-02-22 00:14:25,716 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:25,716 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:25,717 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:25,717 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:25,720 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# 2019-02-22 00:14:25,738 INFO sqlalchemy.engine.base.Engine SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:25,738 - sqlalchemy.engine.base.Engine - INFO - SELECT count(*) AS count_1
# FROM (SELECT thing.id AS thing_id, thing.name AS thing_name, thing.geom AS thing_geom
# FROM thing) AS anon_1
# 2019-02-22 00:14:25,739 INFO sqlalchemy.engine.base.Engine {}
# 2019-02-22 00:14:25,739 - sqlalchemy.engine.base.Engine - INFO - {}
# 2019-02-22 00:14:25,745 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,746 INFO sqlalchemy.engine.base.Engine SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:25,746 - sqlalchemy.engine.base.Engine - INFO - SELECT thing.id AS thing_id, thing.name AS thing_name, ST_AsEWKB(thing.geom) AS thing_geom
# FROM thing
# WHERE ST_Contains(thing.geom, %(ST_Contains_1)s)
# 2019-02-22 00:14:25,747 INFO sqlalchemy.engine.base.Engine {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:25,747 - sqlalchemy.engine.base.Engine - INFO - {'ST_Contains_1': 'POINT(0.5 0.5)'}
# 2019-02-22 00:14:25,749 - tutorial.grpc.geodatas.rpc.search_servicer - INFO - search responses: [response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# , response: "thing: square"
# ]
# ^C
# 2019-02-22 00:15:20,104 - __main__ - INFO - Signal 2 received, shutting down...
# 2019-02-22 00:15:20,105 - tutorial.grpc.geodatas.tools.service_discovery - INFO - unregister started
# 2019-02-22 00:15:20,108 - urllib3.connectionpool - DEBUG - Starting new HTTP connection (1): 127.0.0.1:8500
# 2019-02-22 00:15:20,114 - urllib3.connectionpool - DEBUG - http://127.0.0.1:8500 "PUT /v1/agent/service/deregister/search-service-54808 HTTP/1.1" 200 0
# 2019-02-22 00:15:20,117 - urllib3.connectionpool - DEBUG - http://127.0.0.1:8500 "GET /v1/agent/services HTTP/1.1" 200 162
# 2019-02-22 00:15:20,118 - tutorial.grpc.geodatas.tools.service_discovery - INFO - services: {'search-service-52716': {'ID': 'search-service-52716', 'Service': 'search-service', 'Tags': [], 'Meta': {}, 'Port': 52716, 'Address': '127.0.0.1', 'Weights': {'Passing': 1, 'Warning': 1}, 'EnableTagOverride': False}}

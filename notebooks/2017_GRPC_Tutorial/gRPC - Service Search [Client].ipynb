# %%
# Jupyter trick to see log messages
import logging 
import sys

# Create logger
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

# Create STDERR handler
handler = logging.StreamHandler(sys.stderr)

# Create formatter and add it to the handler
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

# Set STDERR handler as the only handler 
logger.handlers = [handler]

# %% [markdown]
# ## Call gRPC service: search_client

# %%
import tutorial.grpc.geodatas.search_client as search_client

# %% [markdown]
# ### Perform a search request

# %% [markdown]
# #### Build args (parse) for request

# %%
args = "--request_position_latlng 0.5 0.5 --m".split(" ")
args_parsed = search_client.build_parser().parse_args(args)

# %%
for _ in range(100):
    search_client.process(args_parsed)
# Out:
# 2019-02-22 00:14:23,009 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,011 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,029 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,030 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,049 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,056 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,057 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,064 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,066 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,074 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,079 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,080 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,091 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,092 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,099 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,104 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,106 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,113 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,114 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,126 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,134 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,135 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,145 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,146 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,154 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,159 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,160 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,166 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,168 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,178 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,185 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,186 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,194 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,199 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,205 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,210 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,211 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,216 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,217 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,230 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,237 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,243 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,252 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,253 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,262 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,268 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,269 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,276 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,277 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,285 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,291 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,294 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,301 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,302 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,309 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# 2019-02-22 00:14:23,315 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,316 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,329 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,330 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,337 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,345 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,347 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,358 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,360 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,367 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,376 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,377 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,384 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,385 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,392 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,401 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,406 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,413 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,416 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,427 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,431 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,432 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,442 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,443 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,451 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,457 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,459 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,474 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,475 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,486 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,491 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,493 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,502 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,504 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,516 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,521 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,525 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,535 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,537 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,549 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,559 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,562 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,578 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,579 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,588 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,593 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,595 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,611 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,613 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,626 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,631 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,633 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,641 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,642 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,650 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# 2019-02-22 00:14:23,656 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,657 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,665 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,666 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,673 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,678 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,682 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,690 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,691 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,698 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,704 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,705 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,713 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,714 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,722 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,728 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,737 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,753 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,756 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,764 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,770 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,773 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,785 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,788 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,796 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,802 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,805 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,813 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,815 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,823 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,830 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,831 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,838 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,840 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,847 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,853 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,858 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,874 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,875 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,884 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,891 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,893 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,902 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,904 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,914 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,922 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,923 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,931 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,932 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,943 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,953 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,954 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,962 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,963 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,971 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# 2019-02-22 00:14:23,977 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,978 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:23,984 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:23,985 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:23,992 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:23,997 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:23,998 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,004 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,008 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,013 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,026 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,027 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,037 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,039 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,047 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,053 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,054 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,061 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,063 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,070 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,075 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,076 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,082 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,083 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,097 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,102 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,102 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,118 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,119 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,126 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,134 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,136 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,145 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,146 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,158 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,165 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,167 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,174 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,175 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,181 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,185 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,188 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,194 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,195 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,203 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,210 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,211 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,216 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,217 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,237 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,243 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,245 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,257 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,258 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,269 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# 2019-02-22 00:14:24,273 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,274 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,281 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,287 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,296 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,302 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,304 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,313 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,314 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,323 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,331 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,332 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,341 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,342 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,349 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,354 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,355 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,365 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,366 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,374 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,379 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,380 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,386 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,389 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,395 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,400 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,401 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,408 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,410 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,416 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,423 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,425 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,435 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,436 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,445 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,451 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,453 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,465 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,467 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,478 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,486 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,487 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,496 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,497 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,507 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,512 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,513 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,520 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,521 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,530 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,535 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,537 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,545 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,546 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,553 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# 2019-02-22 00:14:24,561 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,562 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,573 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,574 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,580 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,587 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,589 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,598 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,599 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,605 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,612 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,613 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,621 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,622 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,631 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,636 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,641 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,652 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,654 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,660 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,667 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,669 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,683 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,686 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,692 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,699 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,701 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,708 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,710 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,718 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,724 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,725 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,731 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,732 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,741 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,748 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,749 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,756 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,757 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,762 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:24,767 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:24,768 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:24,776 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:24,777 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:24,784 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# ...
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,203 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:25,210 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:25,211 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:25,218 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:25,219 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,229 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:25,234 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:25,235 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:25,244 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:25,246 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,253 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:25,259 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:25,261 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:25,268 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:25,269 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,279 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:25,287 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:25,289 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:25,299 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:25,302 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,309 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:25,315 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:25,316 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:25,328 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:25,330 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,335 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:25,341 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:25,343 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:25,352 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:25,353 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,361 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:25,366 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:25,367 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:25,374 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:25,375 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,383 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:25,390 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:25,393 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:25,399 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:25,400 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,410 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:25,415 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:25,416 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:25,422 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:25,424 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,435 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# 2019-02-22 00:14:25,446 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:25,447 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:25,458 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:25,460 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,469 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:25,478 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:25,479 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:25,485 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:25,487 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,499 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:25,505 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:25,511 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:25,518 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:25,519 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,527 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:25,534 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:25,535 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:25,543 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:25,544 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,549 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:25,553 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:25,556 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:25,565 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:25,566 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,574 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:25,580 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:25,581 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:25,587 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:25,591 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,598 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:25,607 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:25,608 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:25,615 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:25,616 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,623 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:25,630 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:25,631 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:25,638 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:25,640 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,645 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:25,650 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:25,651 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:25,658 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:25,659 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,665 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:25,670 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:25,671 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:25,680 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:25,681 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,689 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
#
# 2019-02-22 00:14:25,695 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:25,696 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:25,703 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:25,710 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,720 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# 2019-02-22 00:14:25,732 - tutorial.grpc.geodatas.search_client - INFO - creating grpc client based on consul data: ip=127.0.0.1 port=54808
# 2019-02-22 00:14:25,733 - tutorial.grpc.geodatas.search_client - DEBUG - args.monitor: True
# 2019-02-22 00:14:25,741 - tutorial.grpc.geodatas.search_client - DEBUG - monitor response: n_things: 4
#
# 2019-02-22 00:14:25,742 - tutorial.grpc.geodatas.search_client - DEBUG - sending request: query: "search_client"
# result_per_page: 10
# lat: 0.5
# lng: 0.5
#
# 2019-02-22 00:14:25,752 - tutorial.grpc.geodatas.search_client - DEBUG - received response: responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
# responses {
#   response: "thing: square"
# }
